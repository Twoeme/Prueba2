# %%
5+5
# Out:
# 10

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
variable_Carro= 10
variable_Carro2= 20

print(variable_Carro + variable_Carro2)
# Out:
# 30

# %%
num1 = int(input("Ingresa el primer número: "))
num2 = int(input("Ingresa el segundo número: "))

if num1 > num2:
    print("El número mayor es:", num1)
elif num2 > num1:
    print("El número mayor es:", num2)
else:
    print("Ambos números son iguales")
# Out:
# El número mayor es: 20

# %%
url="https://github.com/Twoeme/Prueba2/blob/aaab39a800e79f1ca84bd7a9142fa679601ac713/Supply_Food_Data_Descriptions.csv"
pd.read_csv(url)
# Out:
# https://github.com/Twoeme/Prueba2/blob/aaab39a800e79f1ca84bd7a9142fa679601ac713/Supply_Food_Data_Descriptions.csv
